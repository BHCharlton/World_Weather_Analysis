# %%
#Import the dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Create a set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
#Add the latitudes and longitudes into a new list
coords = list(lats_lngs)

# %%
#Import the citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coords:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
#Import requests and the API key
import requests

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5660dad41870c72ef86f2066f498b9b2

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Create an empty list to hold the city data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | ancud
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | pryazha
# Processing Record 6 of Set 1 | ohara
# Processing Record 7 of Set 1 | rocha
# Processing Record 8 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | akdepe
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | morondava
# Processing Record 16 of Set 1 | cherskiy
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | roseburg
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | secovce
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | tarakan
# Processing Record 29 of Set 1 | broome
# Processing Record 30 of Set 1 | road town
# Processing Record 31 of Set 1 | port lincoln
# Processing Record 32 of Set 1 | paamiut
# Processing Record 33 of Set 1 | port hardy
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | maple creek
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 1 | pampa
# Processing Record 39 of Set 1 | vega de alatorre
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | kuchinarai
# Processing Record 46 of Set 1 | samarai
# Processing Record 47 of Set 1 | debre birhan
# Processing Record 48 of Set 1 | broken hill
# Processing Record 49 of Set 1 | sobolevo
# Processing Record 50 of Set 1 | avera
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | kiunga
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | hasaki
# Processing Record 5 of Set 2 | naze
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | grand-santi
# Processing Record 8 of Set 2 | mackay
# Processing Record 9 of Set 2 | tura
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | tarko-sale
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | saint george
# Processing Record 15 of Set 2 | mount isa
# Processing Record 16 of Set 2 | zyryanka
# Processing Record 17 of Set 2 | hirara
# Processing Record 18 of Set 2 | cayenne
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | waitati
# Processing Record 22 of Set 2 | la ronge
# Processing Record 23 of Set 2 | lozovik
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | tadine
# Processing Record 27 of Set 2 | kakching
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | acapulco
# Processing Record 31 of Set 2 | novaya igirma
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | znin
# Processing Record 34 of Set 2 | kalabo
# Processing Record 35 of Set 2 | sibolga
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | ewa beach
# Processing Record 38 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | paralimni
# Processing Record 42 of Set 2 | svetlaya
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | lasa
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | grindavik
# Processing Record 47 of Set 2 | swift current
# Processing Record 48 of Set 2 | manacapuru
# Processing Record 49 of Set 2 | sardarshahr
# Processing Record 50 of Set 2 | arlit
# Processing Record 1 of Set 3 | cagliari
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | bereznik
# Processing Record 4 of Set 3 | kony
# Processing Record 5 of Set 3 | san isidro
# Processing Record 6 of Set 3 | gat
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | sarangani
# Processing Record 9 of Set 3 | hay river
# Processing Record 10 of Set 3 | nacogdoches
# Processing Record 11 of Set 3 | brae
# Processing Record 12 of Set 3 | pisco
# Processing Record 13 of Set 3 | kofarnihon
# City not found. Skipping...
# Processing Record 14 of Set 3 | makat
# Processing Record 15 of Set 3 | namibe
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | guerrero negro
# Processing Record 18 of Set 3 | cabo san lucas
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | sambava
# Processing Record 21 of Set 3 | victoria
# Processing Record 22 of Set 3 | rudnichnyy
# Processing Record 23 of Set 3 | agua dulce
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | antofagasta
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | acarau
# Processing Record 29 of Set 3 | yarada
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | kathmandu
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | sitka
# Processing Record 36 of Set 3 | sunndalsora
# Processing Record 37 of Set 3 | busselton
# Processing Record 38 of Set 3 | comodoro rivadavia
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | tiarei
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | santiago del estero
# Processing Record 43 of Set 3 | buchanan
# Processing Record 44 of Set 3 | tougan
# Processing Record 45 of Set 3 | manta
# Processing Record 46 of Set 3 | port hedland
# Processing Record 47 of Set 3 | bandarbeyla
# Processing Record 48 of Set 3 | pietarsaari
# Processing Record 49 of Set 3 | corozal
# Processing Record 50 of Set 3 | maragogi
# Processing Record 1 of Set 4 | arraial do cabo
# Processing Record 2 of Set 4 | nelson bay
# Processing Record 3 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | preobrazheniye
# Processing Record 7 of Set 4 | bilma
# Processing Record 8 of Set 4 | half moon bay
# Processing Record 9 of Set 4 | murmashi
# Processing Record 10 of Set 4 | sept-iles
# Processing Record 11 of Set 4 | taltal
# Processing Record 12 of Set 4 | mizdah
# Processing Record 13 of Set 4 | fountain hills
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | natal
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | springdale
# Processing Record 18 of Set 4 | kaeo
# Processing Record 19 of Set 4 | ayaviri
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | rapid valley
# Processing Record 22 of Set 4 | mehamn
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | nizhniy odes
# Processing Record 25 of Set 4 | ukiah
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | grass valley
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | umm lajj
# Processing Record 30 of Set 4 | huron
# Processing Record 31 of Set 4 | avarua
# Processing Record 32 of Set 4 | ode
# Processing Record 33 of Set 4 | dolny kubin
# Processing Record 34 of Set 4 | turka
# Processing Record 35 of Set 4 | hofn
# Processing Record 36 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 37 of Set 4 | novoagansk
# Processing Record 38 of Set 4 | kitimat
# Processing Record 39 of Set 4 | wanning
# Processing Record 40 of Set 4 | makakilo city
# Processing Record 41 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 4 | panjakent
# Processing Record 43 of Set 4 | bungu
# Processing Record 44 of Set 4 | pyapon
# Processing Record 45 of Set 4 | billings
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | beloha
# Processing Record 48 of Set 4 | constitucion
# Processing Record 49 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 4 | kodinsk
# Processing Record 1 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 5 | trairi
# Processing Record 3 of Set 5 | la palma
# Processing Record 4 of Set 5 | zaozerne
# Processing Record 5 of Set 5 | limulan
# Processing Record 6 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 5 | ambajogai
# Processing Record 8 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 9 of Set 5 | birao
# Processing Record 10 of Set 5 | pitimbu
# Processing Record 11 of Set 5 | bluff
# Processing Record 12 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | ponoka
# Processing Record 15 of Set 5 | cockburn town
# Processing Record 16 of Set 5 | raymond terrace
# Processing Record 17 of Set 5 | bang phae
# Processing Record 18 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | cooma
# Processing Record 22 of Set 5 | jatibonico
# Processing Record 23 of Set 5 | general roca
# Processing Record 24 of Set 5 | chokurdakh
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | mareeba
# Processing Record 27 of Set 5 | qafsah
# City not found. Skipping...
# Processing Record 28 of Set 5 | lyubeshiv
# City not found. Skipping...
# Processing Record 29 of Set 5 | karratha
# Processing Record 30 of Set 5 | vila do maio
# Processing Record 31 of Set 5 | touba
# Processing Record 32 of Set 5 | kununurra
# Processing Record 33 of Set 5 | norman wells
# Processing Record 34 of Set 5 | bambanglipuro
# Processing Record 35 of Set 5 | port elizabeth
# Processing Record 36 of Set 5 | fortuna
# Processing Record 37 of Set 5 | portland
# Processing Record 38 of Set 5 | meulaboh
# Processing Record 39 of Set 5 | sinnamary
# Processing Record 40 of Set 5 | abha
# Processing Record 41 of Set 5 | lucea
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | kokopo
# Processing Record 44 of Set 5 | freeport
# Processing Record 45 of Set 5 | micco
# Processing Record 46 of Set 5 | gandajika
# Processing Record 47 of Set 5 | vestmannaeyjar
# Processing Record 48 of Set 5 | nouadhibou
# Processing Record 49 of Set 5 | dir
# Processing Record 50 of Set 5 | marrakesh
# Processing Record 1 of Set 6 | castro
# Processing Record 2 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 6 | aksu
# Processing Record 4 of Set 6 | katobu
# Processing Record 5 of Set 6 | ust-barguzin
# Processing Record 6 of Set 6 | carutapera
# Processing Record 7 of Set 6 | raudeberg
# Processing Record 8 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 6 | krasnyy chikoy
# Processing Record 10 of Set 6 | hermosillo
# Processing Record 11 of Set 6 | verkhnevilyuysk
# Processing Record 12 of Set 6 | myanaung
# Processing Record 13 of Set 6 | ixtapa
# Processing Record 14 of Set 6 | camana
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | kulhudhuffushi
# Processing Record 17 of Set 6 | airai
# Processing Record 18 of Set 6 | urumqi
# Processing Record 19 of Set 6 | iglesias
# Processing Record 20 of Set 6 | zhigansk
# Processing Record 21 of Set 6 | sitio novo do tocantins
# Processing Record 22 of Set 6 | lavagna
# Processing Record 23 of Set 6 | ornskoldsvik
# Processing Record 24 of Set 6 | fairbanks
# Processing Record 25 of Set 6 | vao
# Processing Record 26 of Set 6 | novouzensk
# Processing Record 27 of Set 6 | lata
# Processing Record 28 of Set 6 | roald
# Processing Record 29 of Set 6 | yalutorovsk
# Processing Record 30 of Set 6 | kimberley
# Processing Record 31 of Set 6 | pevek
# Processing Record 32 of Set 6 | isangel
# Processing Record 33 of Set 6 | lazaro cardenas
# Processing Record 34 of Set 6 | udachnyy
# Processing Record 35 of Set 6 | talaya
# Processing Record 36 of Set 6 | nelson
# Processing Record 37 of Set 6 | ati
# Processing Record 38 of Set 6 | kahului
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | sukhobuzimskoye
# Processing Record 41 of Set 6 | loikaw
# Processing Record 42 of Set 6 | bukachacha
# Processing Record 43 of Set 6 | dubno
# Processing Record 44 of Set 6 | kasongo-lunda
# Processing Record 45 of Set 6 | aklavik
# Processing Record 46 of Set 6 | leshukonskoye
# Processing Record 47 of Set 6 | taksimo
# Processing Record 48 of Set 6 | katsuura
# Processing Record 49 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | port-gentil
# Processing Record 2 of Set 7 | puerto escondido
# Processing Record 3 of Set 7 | venustiano carranza
# Processing Record 4 of Set 7 | sola
# Processing Record 5 of Set 7 | mandalgovi
# Processing Record 6 of Set 7 | coquimbo
# Processing Record 7 of Set 7 | necochea
# Processing Record 8 of Set 7 | dmitriyevskoye
# Processing Record 9 of Set 7 | huarmey
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | olinda
# Processing Record 12 of Set 7 | lingao
# Processing Record 13 of Set 7 | fare
# Processing Record 14 of Set 7 | kushima
# Processing Record 15 of Set 7 | kirakira
# Processing Record 16 of Set 7 | wellington
# Processing Record 17 of Set 7 | verkhnyaya balkariya
# Processing Record 18 of Set 7 | estelle
# Processing Record 19 of Set 7 | qui nhon
# Processing Record 20 of Set 7 | lethem
# Processing Record 21 of Set 7 | svetlogorsk
# Processing Record 22 of Set 7 | octeville
# Processing Record 23 of Set 7 | ponyri
# Processing Record 24 of Set 7 | pochutla
# Processing Record 25 of Set 7 | luderitz
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | inndyr
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | baghdad
# Processing Record 30 of Set 7 | vila velha
# Processing Record 31 of Set 7 | tigil
# Processing Record 32 of Set 7 | jaen
# Processing Record 33 of Set 7 | treinta y tres
# Processing Record 34 of Set 7 | kaili
# Processing Record 35 of Set 7 | porto murtinho
# Processing Record 36 of Set 7 | pangnirtung
# Processing Record 37 of Set 7 | oakdale
# Processing Record 38 of Set 7 | kem
# Processing Record 39 of Set 7 | ruhengeri
# Processing Record 40 of Set 7 | lavrentiya
# Processing Record 41 of Set 7 | pauri
# Processing Record 42 of Set 7 | baykit
# Processing Record 43 of Set 7 | santa maria
# Processing Record 44 of Set 7 | diamantino
# Processing Record 45 of Set 7 | nadym
# Processing Record 46 of Set 7 | prince rupert
# Processing Record 47 of Set 7 | matara
# Processing Record 48 of Set 7 | lorengau
# Processing Record 49 of Set 7 | wanxian
# Processing Record 50 of Set 7 | maues
# Processing Record 1 of Set 8 | springbok
# Processing Record 2 of Set 8 | opuwo
# Processing Record 3 of Set 8 | kiama
# Processing Record 4 of Set 8 | padang
# Processing Record 5 of Set 8 | henties bay
# Processing Record 6 of Set 8 | taybad
# Processing Record 7 of Set 8 | buluang
# Processing Record 8 of Set 8 | maroantsetra
# Processing Record 9 of Set 8 | siderno
# Processing Record 10 of Set 8 | awjilah
# Processing Record 11 of Set 8 | katangli
# Processing Record 12 of Set 8 | biltine
# Processing Record 13 of Set 8 | rincon
# Processing Record 14 of Set 8 | narathiwat
# Processing Record 15 of Set 8 | lompoc
# Processing Record 16 of Set 8 | oranjemund
# Processing Record 17 of Set 8 | victor harbor
# Processing Record 18 of Set 8 | kruisfontein
# Processing Record 19 of Set 8 | llanes
# Processing Record 20 of Set 8 | namatanai
# Processing Record 21 of Set 8 | teguldet
# Processing Record 22 of Set 8 | saint-georges
# Processing Record 23 of Set 8 | shirokiy
# Processing Record 24 of Set 8 | bambous virieux
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | diffa
# Processing Record 27 of Set 8 | morant bay
# Processing Record 28 of Set 8 | antonina
# Processing Record 29 of Set 8 | denia
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | nazca
# Processing Record 32 of Set 8 | nenjiang
# Processing Record 33 of Set 8 | yulara
# Processing Record 34 of Set 8 | tokat
# Processing Record 35 of Set 8 | aasiaat
# Processing Record 36 of Set 8 | princeton
# Processing Record 37 of Set 8 | tautira
# Processing Record 38 of Set 8 | sur
# Processing Record 39 of Set 8 | lawrenceburg
# Processing Record 40 of Set 8 | sunyani
# Processing Record 41 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 8 | berdigestyakh
# Processing Record 43 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 8 | qasigiannguit
# Processing Record 45 of Set 8 | tuatapere
# Processing Record 46 of Set 8 | moose factory
# Processing Record 47 of Set 8 | micheweni
# Processing Record 48 of Set 8 | dwarka
# Processing Record 49 of Set 8 | bosaso
# Processing Record 50 of Set 8 | dawei
# Processing Record 1 of Set 9 | rio gallegos
# Processing Record 2 of Set 9 | tonantins
# Processing Record 3 of Set 9 | boiu mare
# Processing Record 4 of Set 9 | bikapur
# Processing Record 5 of Set 9 | santa rosa
# Processing Record 6 of Set 9 | samana
# Processing Record 7 of Set 9 | marawi
# Processing Record 8 of Set 9 | alofi
# Processing Record 9 of Set 9 | praya
# Processing Record 10 of Set 9 | jvari
# Processing Record 11 of Set 9 | shangrao
# Processing Record 12 of Set 9 | kankaanpaa
# Processing Record 13 of Set 9 | yinchuan
# Processing Record 14 of Set 9 | beyneu
# Processing Record 15 of Set 9 | chauk
# Processing Record 16 of Set 9 | saint-augustin
# Processing Record 17 of Set 9 | nancha
# Processing Record 18 of Set 9 | vestmanna
# Processing Record 19 of Set 9 | ketchikan
# Processing Record 20 of Set 9 | tarusa
# Processing Record 21 of Set 9 | verkhoyansk
# Processing Record 22 of Set 9 | wilmington
# Processing Record 23 of Set 9 | mayo
# Processing Record 24 of Set 9 | kloulklubed
# Processing Record 25 of Set 9 | vangaindrano
# Processing Record 26 of Set 9 | muscat
# Processing Record 27 of Set 9 | muravlenko
# Processing Record 28 of Set 9 | rasulnagar
# Processing Record 29 of Set 9 | praia da vitoria
# Processing Record 30 of Set 9 | georgiyevskoye
# Processing Record 31 of Set 9 | letterkenny
# Processing Record 32 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 9 | bereda
# Processing Record 34 of Set 9 | moramanga
# Processing Record 35 of Set 9 | yakeshi
# Processing Record 36 of Set 9 | donskoye
# Processing Record 37 of Set 9 | kavaratti
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | bindura
# Processing Record 40 of Set 9 | provideniya
# Processing Record 41 of Set 9 | ust-tsilma
# Processing Record 42 of Set 9 | sorong
# Processing Record 43 of Set 9 | venado tuerto
# Processing Record 44 of Set 9 | sarh
# Processing Record 45 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 9 | leeton
# Processing Record 47 of Set 9 | smithers
# Processing Record 48 of Set 9 | zhezkazgan
# Processing Record 49 of Set 9 | bataipora
# Processing Record 50 of Set 9 | french harbor
# Processing Record 1 of Set 10 | axim
# Processing Record 2 of Set 10 | vostok
# Processing Record 3 of Set 10 | balakovo
# Processing Record 4 of Set 10 | tshane
# Processing Record 5 of Set 10 | bria
# Processing Record 6 of Set 10 | soddy-daisy
# Processing Record 7 of Set 10 | cienaga
# Processing Record 8 of Set 10 | roma
# Processing Record 9 of Set 10 | flinders
# Processing Record 10 of Set 10 | saveh
# Processing Record 11 of Set 10 | qingdao
# Processing Record 12 of Set 10 | mudanjiang
# Processing Record 13 of Set 10 | sao joao da barra
# Processing Record 14 of Set 10 | baft
# Processing Record 15 of Set 10 | alice springs
# Processing Record 16 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 10 | richards bay
# Processing Record 18 of Set 10 | labuhan
# Processing Record 19 of Set 10 | bela vista
# Processing Record 20 of Set 10 | mabaruma
# Processing Record 21 of Set 10 | asmara
# Processing Record 22 of Set 10 | deputatskiy
# Processing Record 23 of Set 10 | obregon
# Processing Record 24 of Set 10 | kagoro
# Processing Record 25 of Set 10 | mecca
# Processing Record 26 of Set 10 | japura
# Processing Record 27 of Set 10 | touros
# Processing Record 28 of Set 10 | kuusamo
# Processing Record 29 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 10 | faya
# Processing Record 31 of Set 10 | ostrovnoy
# Processing Record 32 of Set 10 | sterlitamak
# Processing Record 33 of Set 10 | saint-die
# City not found. Skipping...
# Processing Record 34 of Set 10 | alta gracia
# Processing Record 35 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 10 | sao filipe
# Processing Record 37 of Set 10 | northam
# Processing Record 38 of Set 10 | abu samrah
# Processing Record 39 of Set 10 | foix
# Processing Record 40 of Set 10 | upernavik
# Processing Record 41 of Set 10 | peniche
# Processing Record 42 of Set 10 | onega
# Processing Record 43 of Set 10 | tianjin
# Processing Record 44 of Set 10 | atikokan
# Processing Record 45 of Set 10 | magistralnyy
# Processing Record 46 of Set 10 | jambi
# Processing Record 47 of Set 10 | evensk
# Processing Record 48 of Set 10 | port keats
# Processing Record 49 of Set 10 | pombas
# Processing Record 50 of Set 10 | sungaipenuh
# Processing Record 1 of Set 11 | trelew
# Processing Record 2 of Set 11 | yaroslavl
# Processing Record 3 of Set 11 | sunrise manor
# Processing Record 4 of Set 11 | turner
# Processing Record 5 of Set 11 | krikellos
# Processing Record 6 of Set 11 | lixourion
# Processing Record 7 of Set 11 | pemangkat
# Processing Record 8 of Set 11 | vershino-darasunskiy
# Processing Record 9 of Set 11 | husavik
# Processing Record 10 of Set 11 | port-cartier
# Processing Record 11 of Set 11 | narsaq
# Processing Record 12 of Set 11 | tahta
# Processing Record 13 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 11 | balaipungut
# Processing Record 15 of Set 11 | kattivakkam
# Processing Record 16 of Set 11 | maarianhamina
# Processing Record 17 of Set 11 | mirnyy
# Processing Record 18 of Set 11 | ciuchici
# Processing Record 19 of Set 11 | matagami
# Processing Record 20 of Set 11 | kirensk
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | plettenberg bay
# Processing Record 23 of Set 11 | emba
# Processing Record 24 of Set 11 | emerald
# Processing Record 25 of Set 11 | nome
# Processing Record 26 of Set 11 | iqaluit
# Processing Record 27 of Set 11 | williams lake
# Processing Record 28 of Set 11 | waipawa
# Processing Record 29 of Set 11 | nantucket
# Processing Record 30 of Set 11 | alta floresta
# Processing Record 31 of Set 11 | dalbandin
# Processing Record 32 of Set 11 | izhma
# Processing Record 33 of Set 11 | hobyo
# Processing Record 34 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 11 | srivardhan
# Processing Record 36 of Set 11 | shingu
# Processing Record 37 of Set 11 | klaksvik
# Processing Record 38 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 40 of Set 11 | nabire
# Processing Record 41 of Set 11 | tekeli
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | kumo
# Processing Record 44 of Set 11 | port victoria
# Processing Record 45 of Set 11 | santa rosa de osos
# Processing Record 46 of Set 11 | muroto
# Processing Record 47 of Set 11 | ravar
# Processing Record 48 of Set 11 | porto novo
# Processing Record 49 of Set 11 | sulangan
# Processing Record 50 of Set 11 | palmer
# Processing Record 1 of Set 12 | macapa
# Processing Record 2 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 12 | de aar
# Processing Record 4 of Set 12 | yuryevets
# Processing Record 5 of Set 12 | krasnoarmeyskiy
# Processing Record 6 of Set 12 | de-kastri
# Processing Record 7 of Set 12 | yibin
# Processing Record 8 of Set 12 | ulaanbaatar
# Processing Record 9 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 12 | magadan
# Processing Record 11 of Set 12 | olafsvik
# Processing Record 12 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 13 of Set 12 | quang ngai
# Processing Record 14 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 15 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 12 | soyo
# Processing Record 17 of Set 12 | vuktyl
# Processing Record 18 of Set 12 | scottsbluff
# Processing Record 19 of Set 12 | mitu
# Processing Record 20 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | maracacume
# Processing Record 23 of Set 12 | juba
# Processing Record 24 of Set 12 | atasu
# Processing Record 25 of Set 12 | maan
# Processing Record 26 of Set 12 | alyangula
# Processing Record 27 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 12 | manzhouli
# Processing Record 29 of Set 12 | damghan
# Processing Record 30 of Set 12 | eden
# Processing Record 31 of Set 12 | urulga
# City not found. Skipping...
# Processing Record 32 of Set 12 | grafton
# Processing Record 33 of Set 12 | macamic
# Processing Record 34 of Set 12 | puruliya
# Processing Record 35 of Set 12 | havelock
# Processing Record 36 of Set 12 | muskogee
# Processing Record 37 of Set 12 | kappeln
# Processing Record 38 of Set 12 | amparafaravola
# Processing Record 39 of Set 12 | nishihara
# Processing Record 40 of Set 12 | nyimba
# Processing Record 41 of Set 12 | gulu
# Processing Record 42 of Set 12 | yumen
# Processing Record 43 of Set 12 | viedma
# Processing Record 44 of Set 12 | raseiniai
# Processing Record 45 of Set 12 | krasnoselkup
# Processing Record 46 of Set 12 | kaset sombun
# Processing Record 47 of Set 12 | guanare
# Processing Record 48 of Set 12 | nedjo
# Processing Record 49 of Set 12 | batemans bay
# Processing Record 50 of Set 12 | coos bay
# Processing Record 1 of Set 13 | san rafael
# Processing Record 2 of Set 13 | mikhaylovsk
# Processing Record 3 of Set 13 | nouakchott
# Processing Record 4 of Set 13 | puerto baquerizo moreno
# Processing Record 5 of Set 13 | thio
# Processing Record 6 of Set 13 | puerto del rosario
# Processing Record 7 of Set 13 | cuamba
# Processing Record 8 of Set 13 | nagod
# Processing Record 9 of Set 13 | taitung
# Processing Record 10 of Set 13 | hamilton
# Processing Record 11 of Set 13 | timbiqui
# Processing Record 12 of Set 13 | ulladulla
# Processing Record 13 of Set 13 | olga
# Processing Record 14 of Set 13 | ust-omchug
# Processing Record 15 of Set 13 | kamenka
# Processing Record 16 of Set 13 | belyy yar
# Processing Record 17 of Set 13 | omboue
# Processing Record 18 of Set 13 | bisira
# Processing Record 19 of Set 13 | bhunya
# Processing Record 20 of Set 13 | bouar
# Processing Record 21 of Set 13 | gavle
# Processing Record 22 of Set 13 | hami
# Processing Record 23 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 24 of Set 13 | guilin
# Processing Record 25 of Set 13 | berlevag
# Processing Record 26 of Set 13 | imeni poliny osipenko
# Processing Record 27 of Set 13 | wolgast
# Processing Record 28 of Set 13 | verkhnetulomskiy
# Processing Record 29 of Set 13 | coihaique
# Processing Record 30 of Set 13 | maldonado
# Processing Record 31 of Set 13 | verkhovazhye
# Processing Record 32 of Set 13 | hammerfest
# Processing Record 33 of Set 13 | beringovskiy
# Processing Record 34 of Set 13 | boyolangu
# Processing Record 35 of Set 13 | mityana
# Processing Record 36 of Set 13 | hambantota
# Processing Record 37 of Set 13 | kontagora
# Processing Record 38 of Set 13 | polunochnoye
# Processing Record 39 of Set 13 | san vicente
# Processing Record 40 of Set 13 | sebastian
# Processing Record 41 of Set 13 | lagoa
# Processing Record 42 of Set 13 | kabanjahe
# Processing Record 43 of Set 13 | badajoz
# Processing Record 44 of Set 13 | dudinka
# Processing Record 45 of Set 13 | livramento
# Processing Record 46 of Set 13 | kidal
# Processing Record 47 of Set 13 | mugur-aksy
# Processing Record 48 of Set 13 | tezu
# Processing Record 49 of Set 13 | viru
# Processing Record 50 of Set 13 | quatre cocos
# Processing Record 1 of Set 14 | qandala
# Processing Record 2 of Set 14 | piacabucu
# Processing Record 3 of Set 14 | nayudupeta
# Processing Record 4 of Set 14 | ruginoasa
# Processing Record 5 of Set 14 | lukulu
# Processing Record 6 of Set 14 | turukhansk
# Processing Record 7 of Set 14 | latung
# Processing Record 8 of Set 14 | kisangani
# Processing Record 9 of Set 14 | soe
# Processing Record 10 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 14 | belmonte
# Processing Record 12 of Set 14 | nacozari
# Processing Record 13 of Set 14 | santo tomas
# Processing Record 14 of Set 14 | egvekinot
# Processing Record 15 of Set 14 | radhanpur
# Processing Record 16 of Set 14 | rawson
# Processing Record 17 of Set 14 | kachug
# Processing Record 18 of Set 14 | burns lake
# Processing Record 19 of Set 14 | bowen
# Processing Record 20 of Set 14 | priiskovyy
# Processing Record 21 of Set 14 | gazojak
# Processing Record 22 of Set 14 | newport
# Processing Record 23 of Set 14 | burica
# City not found. Skipping...
# Processing Record 24 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 25 of Set 14 | jijiga
# Processing Record 26 of Set 14 | boueni
# Processing Record 27 of Set 14 | salalah
# Processing Record 28 of Set 14 | kieta
# Processing Record 29 of Set 14 | goundam
# Processing Record 30 of Set 14 | borazjan
# Processing Record 31 of Set 14 | semnan
# Processing Record 32 of Set 14 | labog
# Processing Record 33 of Set 14 | yarovoye
# Processing Record 34 of Set 14 | mocuba
# Processing Record 35 of Set 14 | juazeiro
# Processing Record 36 of Set 14 | akureyri
# Processing Record 37 of Set 14 | port augusta
# Processing Record 38 of Set 14 | skjervoy
# Processing Record 39 of Set 14 | eyl
# Processing Record 40 of Set 14 | lincoln
# Processing Record 41 of Set 14 | grand island
# Processing Record 42 of Set 14 | alpena
# Processing Record 43 of Set 14 | dingle
# Processing Record 44 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 14 | port blair
# Processing Record 46 of Set 14 | ploemeur
# Processing Record 47 of Set 14 | caiaponia
# Processing Record 48 of Set 14 | ishigaki
# Processing Record 49 of Set 14 | ternate
# Processing Record 50 of Set 14 | grootfontein
# Processing Record 1 of Set 15 | sanford
# Processing Record 2 of Set 15 | iguape
# Processing Record 3 of Set 15 | elverum
# Processing Record 4 of Set 15 | korla
# Processing Record 5 of Set 15 | simao
# Processing Record 6 of Set 15 | acurenam
# Processing Record 7 of Set 15 | boulder city
# Processing Record 8 of Set 15 | tessalit
# Processing Record 9 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 10 of Set 15 | belaya gora
# Processing Record 11 of Set 15 | itaituba
# Processing Record 12 of Set 15 | villanueva
# Processing Record 13 of Set 15 | daru
# Processing Record 14 of Set 15 | flin flon
# Processing Record 15 of Set 15 | garissa
# Processing Record 16 of Set 15 | maridi
# Processing Record 17 of Set 15 | sioux lookout
# Processing Record 18 of Set 15 | manggar
# Processing Record 19 of Set 15 | champerico
# Processing Record 20 of Set 15 | sokolo
# Processing Record 21 of Set 15 | ust-koksa
# Processing Record 22 of Set 15 | sao mateus do sul
# Processing Record 23 of Set 15 | bujaru
# Processing Record 24 of Set 15 | cleveland
# Processing Record 25 of Set 15 | luzhou
# Processing Record 26 of Set 15 | buin
# Processing Record 27 of Set 15 | lubao
# Processing Record 28 of Set 15 | ushtobe
# Processing Record 29 of Set 15 | tutoia
# Processing Record 30 of Set 15 | nampula
# Processing Record 31 of Set 15 | luang prabang
# Processing Record 32 of Set 15 | vila franca do campo
# Processing Record 33 of Set 15 | beidao
# Processing Record 34 of Set 15 | loralai
# Processing Record 35 of Set 15 | yashkul
# Processing Record 36 of Set 15 | kuhdasht
# Processing Record 37 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 15 | leningradskiy
# Processing Record 39 of Set 15 | mackenzie
# Processing Record 40 of Set 15 | kashi
# Processing Record 41 of Set 15 | sibu
# Processing Record 42 of Set 15 | pidhorodna
# Processing Record 43 of Set 15 | yambio
# Processing Record 44 of Set 15 | atar
# Processing Record 45 of Set 15 | ryotsu
# Processing Record 46 of Set 15 | simbahan
# Processing Record 47 of Set 15 | sribne
# Processing Record 48 of Set 15 | palmares do sul
# Processing Record 49 of Set 15 | chapada dos guimaraes
# Processing Record 50 of Set 15 | holoby
# Processing Record 1 of Set 16 | miracema do tocantins
# Processing Record 2 of Set 16 | bata
# Processing Record 3 of Set 16 | barinitas
# Processing Record 4 of Set 16 | benguela
# Processing Record 5 of Set 16 | benjamin hill
# Processing Record 6 of Set 16 | hovd
# Processing Record 7 of Set 16 | pozo colorado
# Processing Record 8 of Set 16 | savinka
# Processing Record 9 of Set 16 | pasighat
# Processing Record 10 of Set 16 | koulamoutou
# Processing Record 11 of Set 16 | anadyr
# Processing Record 12 of Set 16 | merauke
# Processing Record 13 of Set 16 | ladario
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Verify at least 500 cities were added to the list
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Rikitea -23.1203 -134.9692     77.36        64         100        5.88
# 1      Barrow  71.2906 -156.7887     -5.78        77          40       10.36
# 2       Ancud -41.8697  -73.8203     46.42        79          19        3.36
# 3     Mataura -46.1927  168.8643     72.48        59          90        5.86
# 4     Pryazha  61.6926   33.6216     22.24        94         100        7.49
# 5       Ohara  35.2500  140.3833     48.15        31         100        7.87
# 6       Rocha -34.4833  -54.3333     65.66        89           2        7.94
# 7  Butaritari   3.0707  172.7902     81.77        77          57       19.22
# 8        Hilo  19.7297 -155.0900     73.13        74           0        3.44
# 9      Atuona  -9.8000 -139.0333     78.10        75          12       14.90
#
#   Country Current Description
# 0      PF     overcast clouds
# 1      US    scattered clouds
# 2      CL          few clouds
# 3      NZ     overcast clouds
# 4      RU          light snow
# 5      JP     overcast clouds
# 6      UY           clear sky
# 7      KI          light rain
# 8      US           clear sky
# 9      PF          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
